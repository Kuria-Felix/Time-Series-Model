# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
craig_data=pd.read_csv("/kaggle/input/craiglist-dataset/craigslist_vehicles.csv")

# %%
# preview the data frame size
print('Number of rows --> ', craig_data.shape[0], 
      '\nNumber of columns --> ', craig_data.shape[1],
      '\n\n')

# prevew the data
craig_data.head()
# Out:
# Number of rows -->  426880
# Number of columns -->  28
#    Unnamed: 0          id                                                url  \
# 0      362773  7307679724  https://abilene.craigslist.org/ctd/d/abilene-2...
# 1      362712  7311833696  https://abilene.craigslist.org/ctd/d/abilene-2...
# 2      362722  7311441996  https://abilene.craigslist.org/ctd/d/abilene-2...
# 3      362771  7307680715  https://abilene.craigslist.org/ctd/d/abilene-2...
# 4      362710  7311834578  https://abilene.craigslist.org/ctd/d/abilene-2...
#
#     region                      region_url  price    year manufacturer  \
# 0  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 1  abilene  https://abilene.craigslist.org   4500  2002.0          bmw
# 2  abilene  https://abilene.craigslist.org   4900  2006.0       toyota
# 3  abilene  https://abilene.craigslist.org   6500  2008.0         ford
# 4  abilene  https://abilene.craigslist.org   6500  2008.0         ford
#
#         model  condition  ...   type paint_color  \
# 0          x5        NaN  ...    NaN         NaN
# 1          x5        NaN  ...    NaN         NaN
# 2       camry  excellent  ...  sedan      silver
# 3  expedition        NaN  ...    NaN         NaN
# 4  expedition        NaN  ...    NaN         NaN
#
#                                            image_url  \
# 0  https://images.craigslist.org/00m0m_iba78h8ty9...
# 1  https://images.craigslist.org/00m0m_iba78h8ty9...
# 2  https://images.craigslist.org/00808_5FkOw2aGjA...
# 3  https://images.craigslist.org/00M0M_i9CoFvVq8o...
# 4  https://images.craigslist.org/00M0M_i9CoFvVq8o...
#
#                                          description county state        lat  \
# 0  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    NaN    tx  32.401556
# 1  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    NaN    tx  32.401556
# 2  2006 TOYOTA CAMRY LE Sedan   Ready To Upgrade ...    NaN    tx  32.453848
# 3  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    NaN    tx  32.401556
# 4  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    NaN    tx  32.401556
#
#         long               posting_date               removal_date
# 0 -99.884713  2021-04-16 00:00:00+00:00  2021-05-02 00:00:00+00:00
# 1 -99.884713  2021-04-24 00:00:00+00:00  2021-04-28 00:00:00+00:00
# 2 -99.787900  2021-04-23 00:00:00+00:00  2021-05-25 00:00:00+00:00
# 3 -99.884713  2021-04-16 00:00:00+00:00  2021-04-26 00:00:00+00:00
# 4 -99.884713  2021-04-24 00:00:00+00:00  2021-05-12 00:00:00+00:00
#
# [5 rows x 28 columns]

# %%
# List of columns to remove
columns_to_remove = ['county', 'id', 'url', 'region', 'region_url', 'image_url', 'lat', 'size', 'long']
# Drop the specified columns
craig_data = craig_data.drop(columns=columns_to_remove)

# %%
craig_data.head()
# Out:
#    Unnamed: 0  price    year manufacturer       model  condition    cylinders  \
# 0      362773   4500  2002.0          bmw          x5        NaN          NaN
# 1      362712   4500  2002.0          bmw          x5        NaN          NaN
# 2      362722   4900  2006.0       toyota       camry  excellent  4 cylinders
# 3      362771   6500  2008.0         ford  expedition        NaN          NaN
# 4      362710   6500  2008.0         ford  expedition        NaN          NaN
#
#   fuel  odometer title_status transmission  VIN drive   type paint_color  \
# 0  gas  184000.0        clean    automatic  NaN   NaN    NaN         NaN
# 1  gas  184000.0        clean    automatic  NaN   NaN    NaN         NaN
# 2  gas  184930.0        clean    automatic  NaN   fwd  sedan      silver
# 3  gas  206000.0        clean    automatic  NaN   NaN    NaN         NaN
# 4  gas  206000.0        clean    automatic  NaN   NaN    NaN         NaN
#
#                                          description state  \
# 0  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    tx
# 1  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...    tx
# 2  2006 TOYOTA CAMRY LE Sedan   Ready To Upgrade ...    tx
# 3  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    tx
# 4  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...    tx
#
#                 posting_date               removal_date
# 0  2021-04-16 00:00:00+00:00  2021-05-02 00:00:00+00:00
# 1  2021-04-24 00:00:00+00:00  2021-04-28 00:00:00+00:00
# 2  2021-04-23 00:00:00+00:00  2021-05-25 00:00:00+00:00
# 3  2021-04-16 00:00:00+00:00  2021-04-26 00:00:00+00:00
# 4  2021-04-24 00:00:00+00:00  2021-05-12 00:00:00+00:00

# %%
# Replace missing values with median for numerical columns
numerical_columns = craig_data.select_dtypes(include=['int64', 'float64'])
craig_data[numerical_columns.columns] = craig_data[numerical_columns.columns].fillna(craig_data[numerical_columns.columns].median())

# %%
# Replace missing values with mode for categorical columns
categorical_columns = craig_data.select_dtypes(include=['object'])
for column in categorical_columns.columns:
    craig_data[column].fillna(craig_data[column].mode()[0], inplace=True)

# %%
# Convert the 'posting_date' column to datetime
craig_data['posting_date'] = pd.to_datetime(craig_data['posting_date'])

# %%
# Set 'posting_date' as the index
craig_data.set_index('posting_date', inplace=True)

# %%
craig_data.head()
# Out:
#                            Unnamed: 0  price    year manufacturer       model  \
# posting_date
# 2021-04-16 00:00:00+00:00      362773   4500  2002.0          bmw          x5
# 2021-04-24 00:00:00+00:00      362712   4500  2002.0          bmw          x5
# 2021-04-23 00:00:00+00:00      362722   4900  2006.0       toyota       camry
# 2021-04-16 00:00:00+00:00      362771   6500  2008.0         ford  expedition
# 2021-04-24 00:00:00+00:00      362710   6500  2008.0         ford  expedition
#
#                            condition    cylinders fuel  odometer title_status  \
# posting_date
# 2021-04-16 00:00:00+00:00       good  6 cylinders  gas  184000.0        clean
# 2021-04-24 00:00:00+00:00       good  6 cylinders  gas  184000.0        clean
# 2021-04-23 00:00:00+00:00  excellent  4 cylinders  gas  184930.0        clean
# 2021-04-16 00:00:00+00:00       good  6 cylinders  gas  206000.0        clean
# 2021-04-24 00:00:00+00:00       good  6 cylinders  gas  206000.0        clean
#
#                           transmission                VIN drive   type  \
# posting_date
# 2021-04-16 00:00:00+00:00    automatic  1FMJU1JT1HEA52352   4wd  sedan
# 2021-04-24 00:00:00+00:00    automatic  1FMJU1JT1HEA52352   4wd  sedan
# 2021-04-23 00:00:00+00:00    automatic  1FMJU1JT1HEA52352   fwd  sedan
# 2021-04-16 00:00:00+00:00    automatic  1FMJU1JT1HEA52352   4wd  sedan
# 2021-04-24 00:00:00+00:00    automatic  1FMJU1JT1HEA52352   4wd  sedan
#
#                           paint_color  \
# posting_date
# 2021-04-16 00:00:00+00:00       white
# 2021-04-24 00:00:00+00:00       white
# 2021-04-23 00:00:00+00:00      silver
# 2021-04-16 00:00:00+00:00       white
# 2021-04-24 00:00:00+00:00       white
#
#                                                                  description  \
# posting_date
# 2021-04-16 00:00:00+00:00  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...
# 2021-04-24 00:00:00+00:00  $4,500 Cash  2002 BMW X5  8 cylinder 4.4L moto...
# 2021-04-23 00:00:00+00:00  2006 TOYOTA CAMRY LE Sedan   Ready To Upgrade ...
# 2021-04-16 00:00:00+00:00  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...
# 2021-04-24 00:00:00+00:00  $6500.00 2008 Ford Expedition  8 cylinder 5.4L...
#
#                           state               removal_date
# posting_date
# 2021-04-16 00:00:00+00:00    tx  2021-05-02 00:00:00+00:00
# 2021-04-24 00:00:00+00:00    tx  2021-04-28 00:00:00+00:00
# 2021-04-23 00:00:00+00:00    tx  2021-05-25 00:00:00+00:00
# 2021-04-16 00:00:00+00:00    tx  2021-04-26 00:00:00+00:00
# 2021-04-24 00:00:00+00:00    tx  2021-05-12 00:00:00+00:00
